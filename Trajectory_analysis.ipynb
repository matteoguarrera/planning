# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df1 = pd.read_csv('mavic/trajectory_04_23_11_53_44.csv')
df2 = pd.read_csv('mavic/trajectory_04_23_11_59_51.csv')

# %%
BC1 = np.array([df1['x'], df1['y'], df1['z']])
BC2 = np.array([df1['x'], df1['y'], df1['z']])

# %%
plt.plot(BC1[0], BC1[1])
plt.plot(BC2[0], BC2[1])
